# %%
#Easy Task_01
#Author Aditi Saha Ria
#ID NO : 20101238

string = input('Please enter here : ')
string = string.lower()
list_of_vowels = ['a', 'e','i','o','u']
new_string = ''
count = 0
for i in string:
  if i in list_of_vowels:
    count += 1
  else:
    new_string += i
count = str(count)
print(new_string+count)

# %%
#Easy Task_02
#Author Aditi Saha Ria
#ID NO : 20101238

string = input()
reverse_string = ''
for i in string[::-1]:
  reverse_string += i
if reverse_string is string:
  print('True')
else:
  print('False')

# %%
#Easy Task_03
#Author Aditi Saha Ria
#ID NO : 20101238

string = input()
new_string = ''
if len(string) < 4:
  print(string)
else:
  for i in string[-3:]:
    new_string += i
  if new_string == 'ful':
    print(string+'ly')
  else:
    print(string+'ful')

# %%
#Medium Task_01
#Author Aditi Saha Ria
#ID NO : 20101238

string = input()
count1 = 0
count2 = 0
for i in string:
  if i>='a' and i<='z':
    count1 += 1
  elif i>='A' and i<='Z':
    count2 += 1
if count1 < count2:
  print(string.upper())
else:
  print(string.lower())

# %%
#Medium Task_02
#Author Aditi Saha Ria
#ID NO : 20101238

string = input()
numbers_string = '0123456789'
count = 0
for i in string:
  if i in numbers_string:
    count += 1
if count == len(string):
  print('NUMBER')
elif count > 0:
  print('MIXED')
else:
  print('WORD')

# %%
#Medium Task_03
#Author Aditi Saha Ria
#ID NO : 20101238

string = input()
value1 = 0
value2 = 0
for i in range(len(string)):
  if string[i]>='A' and string[i]<='Z':
    value1 = i
    break
for i in range(value1, len(string)):
  if string[i]>='A' and string[i]<='Z':
    value2 = i

new_string = ''

for i in string[value1+1:value2]:
  new_string += i

if new_string == '':
  print('BLANK')
else:
  print(new_string)

# %%
#Medium Task_04
#Author Aditi Saha Ria
#ID NO : 20101238

string = input()
if 'too good' in string:
  string = string.replace('too good', 'excellent')
  print(string)
else:
  print(string)
# Out:
# too good
# excellent

# %%
#Hard Task_01
#Author Aditi Saha Ria
#ID NO : 20101238

first_string = input()
second_string = input()
new_string = ''
for i in first_string:
  if i in second_string:
    new_string += i

for i in second_string:
  if i in first_string:
    new_string += i

if new_string == '':
  print('Nothing in common.')
else:
  print(new_string)

# %%
#Hard Task_02
#Author Aditi Saha Ria
#ID NO : 20101238
 
string = input()
new_string = ''
index_value = 0
count = 0
value = -1
for i in range(-1, len(string)*(-1), -1):
  if string[0] == string[i]:
    index_value = i
    break

sub_string_01 = ''
for i in string[index_value:]:
  sub_string_01 += i

sub_string_02 = ''
for i in string[0:index_value*(-1)]:
  sub_string_02 += i

for i in string[index_value*(-1):index_value]:
  new_string += i

if sub_string_01 == sub_string_02 and sub_string_01 in new_string:
  print(sub_string_01)
else:
  print('Not Palindrome Substring')

# %%
#Hard Task_03
#Author Aditi Saha Ria
#ID NO : 20101238
 
string = input()
numbers_string = '0123456789'
count1 = 0
count2 = 0
count3 = 0
count4 = 0
 
for i in string:
  if i in numbers_string:
    count1 += 1
  if (i>=' ' and i<='/')or(i>=':' and i<='@')or(i>='[' and i<='`'or(i>='{' and i<='~')):
    count2 += 1
  if i>='A' and i<='Z':
    count3 += 1
  if i>='a' and i<='z':
    count4 += 1
count = count1+count2+count3+count4
if count1>0 and count2>0 and count3>0 and count4>0:
  print('OK')
elif count1==0 and count2==0 and count3==0 and count4==0:
  print('Please enter a password')
elif count1==0 and count2==0 and count3==0:
  print ('Digit missing, Special character missing, Uppercase character missing')
elif count1==0 and count2==0 and count4==0:
  print ('Digit missing, Special character missing, Lowercase character missing')
elif count1==0 and count3==0 and count4==0:
  print ('Digit missing, Uppercase character missing, Lowercase character missing')
elif count2==0 and count3==0 and count4==0:
  print('Special character missing, Uppercase character missing, Lowercase character missing')
elif count1==0:
  if count2==0:
    print ('Digit missing, Specialcharacter missing')
  elif count3==0:
    print ('Digit missing, Uppercase character missing')
  elif count4==0:
    print ('Digits missing, Lowercase character missing')
  else:
    print ('Digit missing')
elif count2==0:
  if count3==0:
    print ('Special character missing, Uppercase character missing')
  elif count4==0:
    print('Special character missing, Lowercase character missing')
  else:
    print ('Special character missing')
elif count3==0:
  if count4==0:
    print ('Uppercase character missing, Lowercase character missing')
  else:
    print ('Uppercase character missing')
else:
  print ('Lowercase character missing')

# %%
#Easy Task_01
#Author Aditi Saha Ria 
#ID_No : 20101238
def division(a,b):
    if a==0 or b==0 or a==b:
        return 0
    else:
        return (a/b) - (a//b)
first_number = int(input('Please enter first number: '))
second_number = int(input('Plese enter second number: '))
print(division(first_number, second_number))
# Out:
# Please enter first number: 4
# Plese enter second number: 4
# 0

# %%
#Easy Task_02
#Author Aditi Saha Ria 
#ID_No : 20101238
def BMI(height, weight):
    score = round((weight/((height*0.01)**2)),1)
    print(f"Score is {score}", end = "")
    if weight/(height*0.01)**2 > 30:
        return ". You are Obese"
    elif weight/(height*0.01)**2 >= 25:
        return ". You are Overweight"
    elif weight/(height*0.01)**2 >= 18.5:
        return ". You are Normal"
    else:
        return ". You are Underweight"
x = float(input('Please enter your height: '))
y = float(input('Please enter your weight: '))
result = BMI(x, y)
print(result)
# Out:
# Please enter your height: 182.88
# Please enter your weight: 84
# Score is 25.1. You are Overweight

# %%
#Easy Task_03
#Author Aditi Saha Ria 
#ID_No : 20101238
def divisors(min, max, div):
    sum = 0
    for i in range(min,max,1):
        if not i%div:
            sum = sum + i
    return sum
x = int(input('Please enter minimum number: '))
y = int(input('Please enter maximum number: '))
z = int(input('Please enter the divisor: '))
print(divisors(x,y,z))
# Out:
# Please enter minimum number: 3
# Please enter maximum number: 16
# Please enter the divisor: 3
# 45

# %%
#Medium Task_01
#Author Aditi Saha Ria 
#ID_No : 20101238

#function_code
def food_panda_bill(item, location='mohakhali'):
    if location == 'mohakhali' or location == '':
        if item == 'bbq chicken cheese burger':
            bill = 250 + 40 + (250*0.08)
        elif item == 'beef burger':
            bill = 170 + 40 + (170*0.08)
        elif item == 'naga drums':
            bill = 200 + 40 + (200*0.08)
    else:
        if item == 'bbq chicken cheese burger':
            bill = 250 + 60 + (250*0.08)
        elif item == 'beef burger':
            bill = 170 + 60 + (170*0.08)
        elif item == 'naga drums':
            bill = 200 + 60 + (200*0.08)
    return bill

#main_code
x = input('Please enter item name: ')
#updated_x = x.lower()
y = input('Please enter your location: ')
print(food_panda_bill(x.lower(),y.lower()))
# Out:
# Please enter item name: beef BURGER
# Please enter your location: mohakhali
# 223.6

# %%
#Medium Task_02
#Author Aditi Saha Ria 
#ID_No : 20101238

#function_code
def domain(email, new_domain, old_domain = 'sheba.xyz'):
    if old_domain == 'sheba.xyz' or old_domain == '':
        print(f'Unchanged: {email}')
    else:
        list = email.split('@')
        updated_email = list[0] + '@' + new_domain
        print(f'Changed: {updated_email}')

x = input('Please enter your email address: ')
y = input('Please enter your new domain: ')
z = input('Please enter your old domain: ')
domain(x, y, z)
# Out:
# Please enter your email address: x@y
# Please enter your new domain: sheba.xyz
# Please enter your old domain:
# Unchanged: x@y

# %%
#Medium Task_03
#Author Aditi Saha Ria 
#ID_No : 20101238

#function_code
def vowels(name):
    updated_name = name.lower()
    vowel_list = ['a', 'e', 'i', 'o', 'u']
    count = 0
    name_list = []
    for i in updated_name:
        if i in vowel_list:
            count += 1
            name_list.append(i)
    if count == 0:
        return 'No vowels in the name'
    else:
        print('Vowels: ',end='')
        for i in range(len(name_list)):
            if i == len(name_list)-1:
                print(name_list[i], end='. ')
            else:
                print(name_list[i], end=', ')
        print(f'Total number of vowels: {count}')


x = input('Please enter your name: ')
vowels(x)
# Out:
# Please enter your name: Aditi
# Vowels: a, i, i. Total number of vowels: 3

# %%
#Medium Task_04
#Author Aditi Saha Ria 
#ID_No : 20101238

#function_code
def palindrome(word):
    list = word.split(' ')
    str_01 = ''
    for i in list:
        str_01 = str_01 + i
    given_word = str_01.lower()
    str_02 = ''
    for i in given_word[::-1]:
        str_02 = str_02 + i
    reverse_word = str_02.lower()
    if reverse_word == given_word:
        return 'Palindrome'
    else:
        return 'Not a palindrome'

x = input('Please enter a string: ')
print(palindrome (x))

# %%
#Medium Task_04
#Author Aditi Saha Ria 
#ID_No : 20101238

#function_code
def palindrome(word):
    list = word.split(' ')
    str_01 = ''
    for i in list:
        str_01 = str_01 + i
    given_word = str_01.lower()
    str_02 = ''
    for i in given_word[::-1]:
        str_02 = str_02 + i
    reverse_word = str_02.lower()
    if reverse_word == given_word:
        return 'Palindrome'
    else:
        return 'Not a palindrome'

x = input('Please enter a string: ')
print(palindrome (x))

# %%
#Hard Task_01
#Author Aditi Saha Ria
#ID No: 20101238
#Seperate inputs
import datetime

def total(time,money) :
     present_day = datetime.date.today()
     count = 1
     year = ''
     month = ''
     day = ''
     for i in time :#Hard Task_01
#Author Aditi Saha Ria
#ID : 20101238
import datetime
from datetime import date
def bonus_salary(*args):
    count = len(args)
    
    for i in range(0,count,3):
        salary = ''
        joining_day = ''
        bonus = 0
        salary = args[i+1]
        salary = int(salary)
        list=args[i+2].split('-')
        joining_day = list[0]
        joining_day = 2020 - int(joining_day)
        if joining_day < 5:
            bonus = salary * 0.1
        elif joining_day < 11:
            bonus = (salary * 0.1) + 5000
        else:
            bonus = (salary * 0.15) + 15000
        if i+3 == count:
            print(f'{args[i]}: {bonus}')
        else:
            print(f'{args[i]}: {bonus}', end=', ')

bonus_salary('Alice', 20000, '2017-03-21', 'Bob', 50000, '2015-12-23')
          if count < 5 :
               year += i
          elif count >5 and count <8 :
               month += i
          elif count >8 :
               day += i
          count += 1
     joining_day = datetime.date(int(year), int(month), int(day))
     diff = present_day - joining_day
     service_time = diff.days // 365
     if service_time < 5 :
          bonus = money * .10
     elif service_time <=10 :
          bonus = (money*.10)+5000
     else :
          bonus = (money*.15)+15000
     return int(bonus)
count_01 = 1
final= ''
while True :
     name=input()
     if name == '' :
          print(final)
          break
     money = int(input())
     time = input()
     if count_01 == 1 :
          final = name+": "+str(total(time,money))
     elif count_01 > 1 :
          final = final+", "+name+": "+str(total(time,money))
     count_01 += 1

# %%
from datetime import date
today = date.today()
print(str(today))
# Out:
# 2020-07-16

# %%
#Hard Task_02
#Author Aditi Saha Ria
#ID : 20101238
def year_month_day(number):
    year = number//365
    number = number%365
    month = number//30
    day = number%30
    print(f'{year} years, {month} months and {day} days')
x = int(input('Please enter a number: '))
year_month_day(x)

# %%
#Hard Task_03
#Author Aditi Saha Ria
#ID : 20101238
def pragraph(string) :
     new_string=""
     count =1
     for i in string :
          if count == 1 :
               if i == " " :
                    new_string = new_string + i
               else :
                    i=i.upper()
                    new_string = new_string + i
                    count -= 1
          else :
               if i == "." :
                    new_string = new_string + i
                    count += 1
               elif i == "!" :
                    new_string = new_string + i
                    count += 1
               elif i == "?" :
                    new_string = new_string + i
                    count += 1
               else :
                    new_string = new_string + i
     return new_string
x = input()
x = x.lower()
y=pragraph(x)
if " i " in y :
    y = y.replace(" i "," I ")
    #print(y)
if ' i.' in y:
    y = y.replace(" i."," I.")
    #print(y)
if ' i!' in y:
    y = y.replace(" i!"," I!")
    #print(y)
if ' i?' in y:
    y = y.replace(" i?"," I?")
    #print(y)
#else :
 #    print(y)
print(y)
# Out:
# 'dwd i?'
# 'dwd I?'

# %%
#Hard Task_03
#Author Aditi Saha Ria
#ID : 20101238
#import re
def string(paragraph):
    paragraph = paragraph.capitalize()
    
    for i in range(len(paragraph)-1):
        if paragraph[i-1]+paragraph[i]+paragraph[i+1]==' i ':
            paragraph = paragraph[:i]+paragraph[i].upper()+paragraph[i+1:]
        elif paragraph[i-1]+paragraph[i]+paragraph[i+1]==' i.':
            paragraph = paragraph[:i]+paragraph[i].upper()+paragraph[i+1:]
        elif paragraph[i-1]+paragraph[i]+paragraph[i+1]==' i?':
            paragraph = paragraph[:i]+paragraph[i].upper()+paragraph[i+1:]
        elif paragraph[i-1]+paragraph[i]+paragraph[i+1]==' i!':
            paragraph = paragraph[:i]+paragraph[i].upper()+paragraph[i+1:]
        for i in range(len(paragraph )-2):
            if paragraph[i-1]+paragraph[i]=='. ':
                paragraph = paragraph[:i+1]+paragraph[i+1].upper()+paragraph[i+2:]
            elif paragraph[i-1]+paragraph[i]=='? ':
                paragraph = paragraph[:i+1]+paragraph[i+1].upper()+paragraph[i+2:]
            elif paragraph[i-1]+paragraph[i]=='! ':
                paragraph = paragraph[:i+1]+paragraph[i+1].upper()+paragraph[i+2:]
            
    return paragraph
x = input()
x1 = ''
if ord(x[0])>= ord('a') and ord(x[0])<=ord('z'):
  x1 += chr(ord(x[0])-ord('a')+ord('A'))
  print('a')
print(x1)
print(string(x))
# Out:
# ab
# a
# A
# Ab

# %%
string = input()
correct = ''
if ord(string[0])>= ord('a') and ord(string[0])<=ord('z'):
  correct += chr(ord(string[0])-ord('a')+ord('A'))
for i in range(1, len(string)-1):
  if string[i-1]+string[i]+string[i+1]==' i ':
    correct +=  chr(ord(string[i])-ord('a')+ord('A'))
  elif string[i-1]+string[i]+string[i+1]==' i.':
    correct +=  chr(ord(string[i])-ord('a')+ord('A'))
  elif string[i-1]+string[i]+string[i+1]==' i?':
    correct +=  chr(ord(string[i])-ord('a')+ord('A'))
  elif string[i-1]+string[i]+string[i+1]==' i!':
    correct +=  chr(ord(string[i])-ord('a')+ord('A'))
  elif (i>2) and (string[i-2] + string[i-1] == '. ' or string[i-2] + string[i-1] == '? ' or string[i-2] + string[i-1] == '! '):
    correct += chr(ord(string[i])-ord('a')+ord('A'))
  else:
    correct += string[i]
correct += string[-1]

print(correct)
# Out:
# hello. i am aditi. how i knoq you? i.
# Hello. I am aditi. How I knoq you? I.

# %%
string = input()
correct = ''
if ord(string[0])>= ord('a') and ord(string[0])<=ord('z'):
  correct += chr(ord(string[0])-ord('a')+ord('A'))

for i in range(1, len(string)-1):
  if string[i-1]+string[i]+string[i+1]==' i ':
    #print(string[:i] + chr(ord(string[i])-ord('a')+ord('A')) + string[i+1:])
    correct =  correct[:i] + chr(ord(string[i])-ord('a')+ord('A')) + string[i+1:]
  elif string[i-1]+string[i]+string[i+1]==' i.':
    correct =  correct[:i] + chr(ord(string[i])-ord('a')+ord('A')) + string[i+1:]
  elif string[i-1]+string[i]+string[i+1]==' i?':
    correct =  correct[:i] + chr(ord(string[i])-ord('a')+ord('A')) + string[i+1:]
  elif string[i-1]+string[i]+string[i+1]==' i!':
    correct =  correct[:i] + chr(ord(string[i])-ord('a')+ord('A')) + string[i+1:]
  elif (i>2) and (string[i-2] + string[i-1] == '. ' or string[i-2] + string[i-1] == '? ' or string[i-2] + string[i-1] == '! '):
    correct = correct[:i] + chr(ord(string[i])-ord('a')+ord('A')) + string[i+1:]
  else:
    correct = correct[:i] + string[i:]

print(correct)
# Out:
# hello. i am aditi. how i knoq you? i.
# Hello. I am aditi. How I knoq you? I.

# %%
#google shortcut(for me)
#Hard Task_03 
#Author Aditi Saha Ria
#ID : 20101238
import re
def string(paragraph):
    paragraph = paragraph.capitalize() 
    new_paragraph = re.compile('([.!?]\s*)')
    paragraph_list = new_paragraph.split(paragraph)
    updated_paragraph = ''.join([i.capitalize() for i in paragraph_list])
    
    for i in range(len(updated_paragraph)-1):
        if updated_paragraph[i-1]+updated_paragraph[i]+updated_paragraph[i+1]==' i ':
            updated_paragraph = updated_paragraph[:i]+updated_paragraph[i].upper()+updated_paragraph[i+1:]
        elif updated_paragraph[i-1]+updated_paragraph[i]+updated_paragraph[i+1]==' i.':
            updated_paragraph = updated_paragraph[:i]+updated_paragraph[i].upper()+updated_paragraph[i+1:]
        elif updated_paragraph[i-1]+updated_paragraph[i]+updated_paragraph[i+1]==' i?':
            updated_paragraph = updated_paragraph[:i]+updated_paragraph[i].upper()+updated_paragraph[i+1:]
        elif updated_paragraph[i-1]+updated_paragraph[i]+updated_paragraph[i+1]==' i!':
            updated_paragraph = updated_paragraph[:i]+updated_paragraph[i].upper()+updated_paragraph[i+1:]
            
    return updated_paragraph
x = input()
print(string(x))
# Out:
# my favourite animal is a dog. a dog has sharp teeth so that it can eat flesh very easily. do you know my pet dog’s name? i love my pet very much
# My favourite animal is a dog. A dog has sharp teeth so that it can eat flesh very easily. Do you know my pet dog’s name? I love my pet very much
